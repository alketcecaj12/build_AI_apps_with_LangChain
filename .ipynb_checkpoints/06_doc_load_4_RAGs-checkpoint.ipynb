# %%
# Import library
from langchain_community.document_loaders import PyPDFLoader

# Create a document loader for rag_vs_fine_tuning.pdf
loader = PyPDFLoader('doc/d591.pdf')

# Load the document
data = loader.load()
print(data[0])
# Out:
# page_content='Basel Committee
# on Banking Supervision
#
# Consultative Document
#
#
# Principles for the
# management of credit
# risk
#
# Issued for comment by 21 March 2025
#
#
# February 2025' metadata={'producer': 'Adobe PDF Library 24.5.96', 'creator': 'Acrobat PDFMaker 24 for Word', 'creationdate': '2025-02-03T11:08:36+01:00', 'author': 'Basel Committee on Banking Supervision', 'bcbsdocumentstatus': 'Not Published', 'bcbsembargo': '0', 'bcbspressrelease': '0', 'bcbsreadycomms': '0', 'bcbsstatusconsultative': 'Open', 'bcbsstatusfaq': 'Current', 'bcbsstatusguideline': 'Forthcoming', 'bcbsstatusothers': 'Current', 'bcbsstatusqis': 'Current', 'bcbsstatusreport': 'Current', 'bcbsstatussoundpractice': 'Forthcoming', 'bcbsstatusstandard': 'Forthcoming', 'bcbstopic': '8;#Credit risk|e9eaabda-92af-439a-ab3f-5399db2c9116', 'bcbstranslation': '0', 'bcbsworkinggroup': '5;#Supervision and Implementation Group|81a4d025-8b89-424a-8ab0-35d60ca25dd2', 'bisauthors': '', 'bisauthorsstaxhtfield0': '', 'bisbcbsmeetinglocation': 'Basel, Switzerland', 'bisbcbsmeetingzone': 'internal', 'bisbcbspurpose': '', 'bisconfidentiality': 'Restricted', 'bisdocumentdate': 'D:20250102', 'bisdocumenttype': '', 'bisdocumenttypetaxhtfield0': '', 'bisinstitution': '', 'bisinstitutiontaxhtfield0': '', 'bispermalink': ',', 'bisrecipients': '53;#bcbs|a55ca13a-4bf8-4ec7-a61c-fcb252a22108', 'bisrecipientstaxhtfield0': 'bcbs|a55ca13a-4bf8-4ec7-a61c-fcb252a22108', 'bisretention': 'Permanent', 'bistransmission': 'Internal', 'company': 'Bank for International Settlements', 'contenttypeid': '0x010100EFAA5F2F1100AF489ED6831F34F2830801002712380262557C419F0DCE4AF8EF9964', 'ismydocuments': '0', 'keywords': '', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_actionid': 'e412a938-7da4-436a-88e3-e5d76604d8a2', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_contentbits': '0', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_enabled': 'true', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_method': 'Privileged', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_name': 'Public - No Marking', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_setdate': '2025-02-03T10:06:27Z', 'msip_label_b142c856-5923-4773-b42c-1087be44a18e_siteid': '03e82858-fc14-4f12-b078-aac6d25c87da', 'meeting type': 'In-Person Meeting', 'meeting_x0020_type': 'In-Person Meeting', 'moddate': '2025-02-03T14:24:10+01:00', 'sourcemodified': '', 'subject': 'Principles for the management of credit risk - 2025 consultative document, 5 February 2025', 'taxkeyword': '', 'taxkeywordtaxhtfield': '', 'title': 'Principles for the management of credit risk - 2025 consultative document', '_dlc_dociditemguid': '908f7bc0-dfb3-436c-b8da-af63b86bb220', 'd8ae2100287945569126ffed896d265d': 'Basel Consultative Group|c4997b12-b61c-4ae9-bbb4-4e605d4a76cb', 'e8b9cebad9e74503a338faff26544689': 'Basel core principles|7fb056e6-0a93-43bb-be19-49324cd88552', 'source': 'doc/d591.pdf', 'total_pages': 23, 'page': 0, 'page_label': '1'}

# %%
# !pip install --upgrade accelerate
# Out:
# Requirement already satisfied: accelerate in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (0.27.2)
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (6.1.1)
# Requirement already satisfied: pyyaml in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (2023.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.2)
# Requirement already satisfied: requests in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: sympy in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from sympy->torch>=2.0.0->accelerate) (1.3.0)
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 6.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.27.2
#     Uninstalling accelerate-0.27.2:
#       Successfully uninstalled accelerate-0.27.2
# Successfully installed accelerate-1.13.0
