# %% [markdown]
# ### Data loader

# %%
# Import library
from langchain_community.document_loaders.csv_loader import CSVLoader

# Create a document loader for fifa_countries_audience.csv
loader = CSVLoader('doc/electricity_consumption.csv')

# Load the document
data = loader.load()
print(data[0])
# Out:
# page_content='Datetime (UTC): 2024-01-01 00:00:00
# Country: Armenia
# Zone name: Armenia
# Zone id: AM
# Carbon intensity gCO₂eq/kWh (direct): 181.18
# Carbon intensity gCO₂eq/kWh (Life cycle): 246.79
# Carbon-free energy percentage (CFE%): 51.03
# Renewable energy percentage (RE%): 6.05
# Data source: EMBER + Electricity Maps Estimation
# Data estimated: true
# Data estimation method: ESTIMATED_GENERAL_PURPOSE_ZONE_MODEL' metadata={'source': 'doc/electricity_consumption.csv', 'row': 0}
