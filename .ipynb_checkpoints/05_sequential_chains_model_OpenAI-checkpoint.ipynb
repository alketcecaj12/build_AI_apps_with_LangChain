# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts import FewShotPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Building prompts for sequential chains
# Application for helping people learn new skills.
# This system needs to be built sequentially, so learners can
# modify plans based on their preferences and constraints.
# This eaxmple utilizes LangChain LCEL skills to build a
# sequential chain to build this system, and the first step is
# to design the prompt templates that will be used by this
# system.

# %%
# Create a prompt template that takes an input activity
learning_prompt = PromptTemplate(
    input_variables=["activity"],
    template="I want to learn how to {activity}. Can you suggest how I can learn this step-by-step?"
)

# Create a prompt template that places a time constraint on the output
time_prompt = PromptTemplate(
    input_variables=["learning_plan"],
    template="I only have one week. Can you create a plan to help me hit this goal: {learning_plan}."
)

# Invoke the learning_prompt with an activity
print(learning_prompt.invoke({"activity": "play golf"}))
# Out:
# text='I want to learn how to play golf. Can you suggest how I can learn this step-by-step?'

# %%
# Create an OpenAI chat LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY")  
)

# %%
# Complete the sequential chain with LCEL
seq_chain = ({"learning_plan": learning_prompt | llm | StrOutputParser()}
    | time_prompt
    | llm
    | StrOutputParser())

# Call the chain
print(seq_chain.invoke({"activity": "play the harmonica"}))
# Out:
# Here's a detailed one-week plan based on the steps provided to help you kickstart your journey with the harmonica. Each day will focus on a specific set of skills or concepts to keep your learning structured and manageable.
#
# ### One-Week Harmonica Learning Plan
#
# #### Day 1: Getting Started
# - **Choose Your Harmonica**: Purchase or gather your diatonic harmonica in the key of C.
# - **Familiarize Yourself**: Learn about the parts of the harmonica (holes, cover plates, reed plates).
# - **Holding the Instrument**: Practice holding the harmonica correctly.
# - **Basic Breathing**: Spend at least 10 minutes just breathing in and out through the harmonica.
#
# #### Day 2: Mastering Basic Techniques
# - **Single Notes**: Practice isolating single notes by using your lips and tongue. Focus on holes 4, 5, and 6.
# - **Practice Bending**: Once comfortable with single notes, spend time trying to bend a note from hole 4. Note bending provides an expressive quality to your playing.
# ...
