# %% [markdown]
# ### Splitting text
#
# A key process in implementing Retrieval Augmented Generation (RAG) is splitting documents into chunks for storage in a vector database.
#
# There are several splitting strategies available in LangChain, some with more complex routines than others. In this exercise, you'll implement a character text splitter, which splits documents based on characters and measures the chunk length by the number of characters.
#
# Remember that there is no ideal splitting strategy, you may need to experiment with a few to find the right one for your use case.

# %%
# Import the character splitter
from langchain_text_splitters import CharacterTextSplitter

quote = 'Words are flowing out like endless rain into a paper cup,\nthey slither while they pass,\nthey slip away across the universe.'
chunk_size = 24
chunk_overlap = 10

# Create an instance of the splitter class
splitter = CharacterTextSplitter(
    separator='\n',
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap)

# Split the string and print the chunks
docs = splitter.split_text(quote) 
print(docs)
print([len(doc) for doc in docs])
# Out:
# Created a chunk of size 57, which is longer than the specified 24
# Created a chunk of size 29, which is longer than the specified 24
# ['Words are flowing out like endless rain into a paper cup,', 'they slither while they pass,', 'they slip away across the universe.']
# [57, 29, 35]

# %% [markdown]
# ## Recursive text splitter

# %%
# Import the recursive character splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

quote = 'Words are flowing out like endless rain into a paper cup,\nthey slither while they pass,\nthey slip away across the universe.'
chunk_size = 24
chunk_overlap = 10

# Create an instance of the splitter class
splitter = RecursiveCharacterTextSplitter(
    separators=["\n", " ", ""],
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap)

# Split the document and print the chunks
docs = splitter.split_text(quote) 
print(docs)
print([len(doc) for doc in docs])
# Out:
# ['Words are flowing out', 'out like endless rain', 'rain into a paper cup,', 'they slither while they', 'they pass,', 'they slip away across', 'across the universe.']
# [21, 21, 22, 23, 10, 21, 20]

# %% [markdown]
# ### HTML split

# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader
# Load the HTML document into memory
loader = UnstructuredHTMLLoader("doc/Good Web Page Examples _ Leadpages _ Leadpages.html")
data = loader.load()

# Define variables
chunk_size = 300
chunk_overlap = 100

# Split the HTML
splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    separators=['.'])

docs = splitter.split_documents(data) 
print(docs)
# Out:
# [Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='In This Article\n\n10 Good Web Page Examples\n\n1. Apple\n\n2. Airbnb\n\n3. Dropbox\n\n4. The New York Times\n\n5. TED\n\n6. Slack\n\n7. Medium\n\n8. Spotify\n\n9. Asana\n\n10'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='. Marvel\n\nFAQ: Good Web Page Examples\n\nHow do the top 10 web pages nail UX, design, and copy?\n\nWhat features do good web pages typically have?\n\nWhy are these 10 examples considered to have good web design?\n\nConclusion\n\nBLOG / DIGITAL MARKETING\n\n10 Good Web Page Examples That Nail UX, Design & Copy\n\nLeadpages\n\nBy Jaden Montag|Published June 22, 2025|Updated February 3, 2026\n\nIn the digital age, where first impressions are often formed online, a website’s design can make or break how users perceive a brand or service'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='. Spotting good web page examples can offer insight and inspiration for those seeking to enhance their sites'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='. This article showcases 10 examples of websites that deliver outstanding user experience (UX), design, and copy, serving as a benchmark for creating engaging and functional web spaces that stand out in 2024’s best website designs'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='. Welcoming you into this journey of creativity and brilliance, let’s delve into page website designs, and amazing website designs that have set new standards.\n\n10 Good Web Page Examples\n\n1. Apple\n\nApple’s site is the epitome of minimalism paired with functionality'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='. Apple\n\nApple’s site is the epitome of minimalism paired with functionality. Their web page design is simple yet powerful, ensuring users get what they need without unnecessary fluff'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='.\n\nThe use of white space, clean typography, and high-resolution images allows the product to be the hero while making navigation intuitive.\n\nWith each scroll, users are pulled into a seamless narrative about cutting-edge technology'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content=".\n\nWith each scroll, users are pulled into a seamless narrative about cutting-edge technology.\n\nApple's consistent brand image over the years reinforces their authority and innovation, guiding design trends around the globe.\n\n2"), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='.\n\n2. Airbnb\n\nAirbnb offers a user-friendly interface that balances visuals with text, a clear protocol for a smooth user journey.\n\nThe homepage’s search functionality is bold and inviting, enabling users to dive directly into searching for properties without delay'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='.\n\nAirbnb’s story-telling approach through imagery and customer testimonials exemplifies how copy and visuals can intertwine to engage effectively.\n\nIts consistent design language and community-driven content make it trustworthy while promoting a sense of global belonging.\n\n3'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages _ Leadpages.html'}, page_content='.\n\n3. Dropbox\n\nDropbox’s webpage drives home its cloud storage benefits with a straightforward approach.\n\nThe homepage is rich with calls-to-action, enabling easy access to sign-up journeys without overwhelming users'), Document(metadata={'source': 'doc/Good Web Page Examples _ Leadpages  ...
