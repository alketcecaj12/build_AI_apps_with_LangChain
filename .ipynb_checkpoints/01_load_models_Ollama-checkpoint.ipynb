# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate

llm = OllamaLLM(model="llama3.2")  # ✅ uses your local Ollama

# %%
# Predict the words following the text in question
prompt = 'Three reasons for using LangChain for LLM application development.'
response = llm.invoke(prompt)

# %%
print(response)
# Out:
# LangChain is a Python library that provides a flexible and efficient way to integrate large language models (LLMs) with various applications. Here are three reasons for using LangChain for LLM application development:
#
# 1. **Efficient Model Management**: LangChain simplifies the management of large LLMs by providing a set of tools and abstractions that allow developers to efficiently store, load, and update model weights. This enables developers to focus on building their applications rather than worrying about the underlying infrastructure. With LangChain, you can easily switch between different models, versions, or even languages without having to rewrite your application from scratch.
#
# 2. **Decoupling of Application Logic**: LangChain's modular design allows developers to decouple their application logic from the LLM itself. This means that you can focus on building your specific use case or workflow without being tied to a particular model architecture or implementation. You can also easily experiment with different models, algorithms, or techniques without affecting your entire application.
#
# 3. **Streamlined Integration and Deployment**: LangChain provides a standardized interface for integrating LLMs with various applications, making it easier to deploy and scale your application in the cloud or on-premises. With LangChain, you can use popular frameworks like AWS Sagemaker, Google Cloud AI Platform, or Azure Machine Learning to manage your LLM models and workflows. Additionally, LangChain's API allows for seamless integration with other tools and services, making it easier to incorporate LLMs into your existing tech stack.
#
# Overall, LangChain offers a flexible and scalable platform for developing LLM-based applications, allowing developers to focus on building innovative solutions rather than getting bogged down in the underlying infrastructure.
