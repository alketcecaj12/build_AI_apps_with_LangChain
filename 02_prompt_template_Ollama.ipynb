# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate

llm = OllamaLLM(model="llama3.2")  # ✅ uses your local Ollama

# %%
from langchain_core.prompts import PromptTemplate

template = "Answer the question briefly.\nQuestion: {question}\nAnswer:"
prompt = PromptTemplate.from_template(template)

chain = prompt | llm
response = chain.invoke({"question": "What is LangChain?"})
print(response)
# Out:
# LangChain is an open-source protocol that enables interoperability between blockchain networks, allowing for seamless data sharing and processing across different chains.
